# %% [markdown]
# ## 📊 Run Experiments on MyCreation Dataset

# %%
# Run 20 experiments with different seeds for My Creation dataset 
# !python run_multiple_experimentsNewDataset.py --num_runs 20 --dataset "mycreation/combined_dataframe_ASX200_raw_clean"
