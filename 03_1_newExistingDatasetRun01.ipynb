# %% [markdown]
# ## 📊 Run Experiments on New Existing Dataset

# %%
# "existingDataset\combined_dataframe_AAPL"
# "existingDataset\combined_dataframe_CNN_SP500"

# !python run_multiple_experimentsNewDataset.py --num_runs 20 --dataset "existingDataset/combined_dataframe_CNN_SP500_raw_clean"
